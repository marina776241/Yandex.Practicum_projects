# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Открытие-файлов-с-данными-и-изучение-общей-информации" data-toc-modified-id="Открытие-файлов-с-данными-и-изучение-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Открытие файлов с данными и изучение общей информации</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Замена-названия-столбцов" data-toc-modified-id="Замена-названия-столбцов-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Замена названия столбцов</a></span></li><li><span><a href="#Замена-типов-данных" data-toc-modified-id="Замена-типов-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Замена типов данных</a></span></li><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка пропусков</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Релизы-игр-по-годам" data-toc-modified-id="Релизы-игр-по-годам-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Релизы игр по годам</a></span></li><li><span><a href="#Продажи-по-платформам" data-toc-modified-id="Продажи-по-платформам-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Продажи по платформам</a></span></li><li><span><a href="#Актуальный-период" data-toc-modified-id="Актуальный-период-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Актуальный период</a></span></li><li><span><a href="#Потенциально-прибыльные-платформы" data-toc-modified-id="Потенциально-прибыльные-платформы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Потенциально прибыльные платформы</a></span></li><li><span><a href="#Глобальные-продажи-игр-в-разбивке-по-платформам" data-toc-modified-id="Глобальные-продажи-игр-в-разбивке-по-платформам-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Глобальные продажи игр в разбивке по платформам</a></span></li><li><span><a href="#Влияние-на-продажи-отзывов-пользователей-и-критиков" data-toc-modified-id="Влияние-на-продажи-отзывов-пользователей-и-критиков-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Влияние на продажи отзывов пользователей и критиков</a></span></li><li><span><a href="#Самые-прибыльные-жанры" data-toc-modified-id="Самые-прибыльные-жанры-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Самые прибыльные жанры</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-каждого-региона" data-toc-modified-id="Портрет-пользователя-каждого-региона-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Портрет пользователя каждого региона</a></span><ul class="toc-item"><li><span><a href="#Самые-популярные-платформы-для-каждого-региона" data-toc-modified-id="Самые-популярные-платформы-для-каждого-региона-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Самые популярные платформы для каждого региона</a></span></li><li><span><a href="#Самые-популярные-жанры-для-каждого-региона" data-toc-modified-id="Самые-популярные-жанры-для-каждого-региона-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Самые популярные жанры для каждого региона</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-отдельном-регионе-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в отдельном регионе</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Общий-комментарий" data-toc-modified-id="Общий-комментарий-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Общий комментарий</a></span></li></ul></div>

# %% [markdown]
# # Закономерности, определяющие успешность игры

# %% [markdown]
# **Описание проекта**
#
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# **Описание данных**
#
# * Name — название игры
# * Platform — платформа
# * Year_of_Release — год выпуска
# * Genre — жанр игры
# * NA_sales — продажи в Северной Америке (миллионы проданных копий)
# * EU_sales — продажи в Европе (миллионы проданных копий)
# * JP_sales — продажи в Японии (миллионы проданных копий)
# * Other_sales — продажи в других странах (миллионы проданных копий)
# * Critic_Score — оценка критиков (максимум 100)
# * User_Score — оценка пользователей (максимум 10)
# * Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# **План работы над проектом:**
#
#
# **Шаг 1. Открыть файл с данными и изучить общую информацию**
#
#
# **Шаг 2. Подготовить данные**
#
# * Заменить названия столбцов (приведите к нижнему регистру);
# * Преобразовать данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# * Обработать пропуски при необходимости;
# * Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
#
# **Шаг 3. Провести исследовательский анализ данных**
#
# * Посмотреть, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# * Посмотреть, как менялись продажи по платформам. Выбрать платформы с наибольшими суммарными продажами и построить распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# * Взять данные за соответствующий актуальный период. Актуальный период определить самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывайте в работе данные за предыдущие годы.
# * Какие платформы лидируют по продажам, растут или падают? Выберать несколько потенциально прибыльных платформ.
# * Построить график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Описать результат.
# * Посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Построить диаграмму рассеяния и посчитать корреляцию между отзывами и продажами. Сформулировать выводы.
# * Соотнести выводы с продажами игр на других платформах.
# * Посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
#
# **Шаг 4. Составить портрет пользователя каждого региона**
#
# Определить для пользователя каждого региона (NA, EU, JP):
# * Самые популярные платформы (топ-5). Описать различия в долях продаж.
# * Самые популярные жанры (топ-5). Пояснить разницу.
# * Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
#
# **Шаг 5. Проверьте гипотезы**
#
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
#
# **Шаг 6. Написать общий вывод**

# %% [markdown]
# ## Открытие файлов с данными и изучение общей информации

# %%
# импортируем необходимые библиотеки
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats as st

import warnings
warnings.filterwarnings('ignore')

# %%
#df_game = pd.read_csv('games.csv')
df_game = pd.read_csv('/datasets/games.csv')

# %%
# Сброс ограничений на количество выводимых рядов
pd.set_option('display.max_rows', None)

# Сброс ограничений на число столбцов
pd.set_option('display.max_columns', None)

# Сброс ограничений на количество символов в записи
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Выведем информацию о таблице, значения столбцов и несколько строк:

# %%
# Для отображения всех столбцов сделаем цикл, который выводит каждый столобец по очереди 
# (его уникальные значения и их количество)
def columns_info(data_frame):
    for column in data_frame.columns:
        print(column)
        display(data_frame[column].value_counts())  # исправила
        display(data_frame[column].unique()) # исправила
        print()

# %%
columns_info(df_game)
# Out:
# Name
# Need for Speed: Most Wanted                                                                                                             12
# FIFA 14                                                                                                                                  9
# Madden NFL 07                                                                                                                            9
# Ratatouille                                                                                                                              9
# LEGO Marvel Super Heroes                                                                                                                 9
# The LEGO Movie Videogame                                                                                                                 8
# LEGO Jurassic World                                                                                                                      8
# ...

# %%
df_game.info()
df_game.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB
#                                                  Name Platform  \
# 2389                         Phantasy Star Portable 2      PSP
# 6739                        Major League Baseball 2K7      PS3
# 8712                            MTV Music Generator 2      PS2
# 16553                          Farming Simulator 2014      PSV
# ...

# %%
df_game.describe()
# Out:
#        Year_of_Release      NA_sales      EU_sales      JP_sales  \
# count     16446.000000  16715.000000  16715.000000  16715.000000
# mean       2006.484616      0.263377      0.145060      0.077617
# std           5.877050      0.813604      0.503339      0.308853
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2016.000000     41.360000     28.960000     10.220000
#
#         Other_sales  Critic_Score
# count  16715.000000   8137.000000
# mean       0.047342     68.967679
# std        0.186731     13.938165
# min        0.000000     13.000000
# 25%        0.000000     60.000000
# 50%        0.010000     71.000000
# 75%        0.030000     79.000000
# max       10.570000     98.000000

# %% [markdown]
# ### Вывод

# %% [markdown]
# По первому осмотру таблицы и данных можно сделать следующие выводы:
#
# * Необходимо привести к нижнему регистру названия колонок;
# * В столбцах `Name` и `Genre` есть 2 пропуска;
# * В столбце `Year_of_Release` 269 пропусков;
# * В столбцах `Critic_Score`, `User_Score` и `Rating` больше всего пропусков (почти половина данных отсутствует);
# * В столбце `User_Score` нужно изменить тип данных на float;
# * В столбцах `Year_of_Release`, `Critic_Score` нужно изменить тип данных на целочисленный.

# %%
display(df_game['Platform'].value_counts())
display(df_game['Platform'].unique())
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       29
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Замена названия столбцов

# %% [markdown]
# Заменим названия столбцов, для этого применим метод `.lower()`, который приведет все названия к нижнему регистру:

# %%
df_game.columns = df_game.columns.str.lower()

# %%
df_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ### Замена типов данных

# %% [markdown]
# Нам необходимо заменить типы данных в столбцах:
# * `year_of_release`
# * `critic_score`
# * `user_score`
#
#
# Но из-за пропусков будет ошибка, поэтому сначала необходимо обработать пропуски и потом заменить тип данных.

# %%
# df_game['year_of_release'] = df_game['year_of_release'].astype('int')
# df_game['critic_score'] = df_game['critic_score'].astype('int')
# df_game['user_score'] = df_game['user_score'].astype('float')

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Выведем список пропущенных значений по столбцам:

# %%
display(df_game.isna().sum())
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Посмотрим каждый столбец с пропусками и, проанализировав пропуски, решим, что с ними делать.

# %% [markdown]
# Начнем со столбца `name`:

# %%
display(df_game[df_game['name'].isna()])
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        other_sales  critic_score user_score rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# В данных строках кроме количества продаж нет никакой информации, ничего восстановить не получится, поэтому удалим их:

# %%
df_game.drop(labels=[659,14244],inplace=True)

# %%
display(df_game.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release     269
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         6699
# rating             6764
# dtype: int64

# %% [markdown]
# Теперь посмотри на пропуски столбца `year_of_release`:

# %%
display(df_game[df_game['year_of_release'].isna()])
# Out:
#                                                     name platform  \
# 183                                      Madden NFL 2004      PS2
# 377                                     FIFA Soccer 2004      PS2
# 456                           LEGO Batman: The Videogame      Wii
# 475                           wwe Smackdown vs. Raw 2006      PS2
# 609                                       Space Invaders     2600
# 627                                            Rock Band     X360
# 657             Frogger's Adventures: Temple of the Frog      GBA
# 678          LEGO Indiana Jones: The Original Adventures      Wii
# 719                                       Call of Duty 3      Wii
# 805                                            Rock Band      Wii
# 1131                             Call of Duty: Black Ops       PC
# 1142                                           Rock Band      PS3
# 1301                                      Triple Play 99       PS
# ...

# %% [markdown]
#  Проанализировав пропуски, можно заметить игры жанра Sports, где в названии указан год, следющий за годом выпуска, в играх жанра Racing в названии указан год выпуска.

# %%
#display(df_game.query('genre in ("Sports",  "Racing")')[df_game['year_of_release'].isna()])

# %%
display(df_game.query('genre in ("Sports",  "Racing")')[df_game['year_of_release'].isna()]['name'].count())
# Out:
# 65

# %% [markdown]
# 65 значений из 16713 строк это 0,39% данных. Этого мало, чтобы тратить время на написание функции, которая будет искать в названии год и вычетать из него 1 или не вычетать в зависимости от жанра (из 65 не во всех есть год в названии).
#
#
# Всего пропусков 269, что составляет 1,61%. Так как в остальных столбцах есть важные для нас данные (например, платформа и количество продаж игры), то удалять эти строки не целесообразно, поэтому заполним их целым числом, удобным  при анализе(например, -1), а при построении графика года выхода игры сделаем срез больше нуля и эти 269 строк не испортят вид графика.

# %%
df_game['year_of_release'].fillna(value=-1, inplace=True)

# %%
display(df_game.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         6699
# rating             6764
# dtype: int64

# %% [markdown]
# Теперь посмотри на пропуски столбца `rating`:

# %%
print(df_game['rating'].value_counts())
print(df_game['rating'].unique())
# Out:
# E       3990
# T       2961
# M       1563
# E10+    1420
# EC         8
# RP         3
# K-A        3
# AO         1
# Name: rating, dtype: int64
# ['E' nan 'M' 'T' 'E10+' 'K-A' 'AO' 'EC' 'RP']

# %% [markdown]
# Назначающей возрастной рейтинг для игр в Штатах является организация ESRB, всего есть 7 вариантов рейтинга, куда не входит `K-A` в данный момент.
# По информации из Интернета, сначала было всего 5 вариантов рейтинга, где и было такое наименование:
#
# K-A: Для детей – для тех, кто уже научился говорить и держать джойстик, эти игры уже могут вызывать интерес [позже в 1998 году был переименован в Е – для всех возрастов, а также чуть позже был добавлен рейтинг Е10+, как промежуточный между Е и Т]
#
#
# Поэтому можно заменить его на значение E.

# %%
df_game['rating'] = df_game['rating'].replace('K-A', 'E')

# %%
print(df_game['rating'].value_counts())
print(df_game['rating'].unique())
# Out:
# E       3993
# T       2961
# M       1563
# E10+    1420
# EC         8
# RP         3
# AO         1
# Name: rating, dtype: int64
# ['E' nan 'M' 'T' 'E10+' 'AO' 'EC' 'RP']

# %%
display(df_game[df_game['rating'].isna()].sample(10))
# Out:
#                                                     name platform  \
# 15043                                  Kami Naru Kimi to      PSP
# 10293                                      Langrisser IV      SAT
# 11686                    Scooby-Doo! Who's Watching Who?      PSP
# 16378                           Slide Adventure: Mag Kid       DS
# 11354                     Tokimeki Memorial: Girl's Side      PS2
# 16291  Simple 2000 Series Vol. 120: The Saigo no Nipp...      PS2
# 8333     Disney TH!NK Fast: The Ultimate Trivia Showdown      PS2
# 15902                                       Custom Drive      PSP
# 7956              J-League Pro Soccer Club o Tsukurou! 5      PS2
# 10541                        Metal Gear Solid HD Edition      PS3
#
#        year_of_release      genre  na_sales  eu_sales  jp_sales  other_sales  \
# 15043           2011.0  Adventure      0.00      0.00      0.02         0.00
# 10293           1997.0   Strategy      0.00      0.00      0.11         0.00
# ...

# %% [markdown]
# В столбце 6764 пропуска из 16713, то есть 40,47%. Почти половина. Эти данные можно было бы восстановить, если бы у нас было больше данных или меньше пропусков в зависимоси от жанра игры.
#
# Также при анализе влияние рейтинга на продажи в зависимости от региона наши усредненные значения будут выбиваться, так как помимо жанра все же есть разные условия установки рейтинга. Информация из интернета:
#
# "Оценка проводится по нескольким основным позициям. Эксперты раскладывают игру на элементы, которые учитываются в рейтинге, и сверяют их со списком. За каждый элемент начисляется определенное число штрафных очков. Результаты плюсуются, и в зависимости от получившейся суммы выставляется итоговый рейтинг."
# Всего 22 критерия.
#
# Поэтому, как в случае с годом, лучше заменить пропуски целочисленным значением и при построении графиков делать срез без учета этих значений.

# %%
df_game['rating'].fillna(value=-1, inplace=True)

# %%
display(df_game.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         6699
# rating                0
# dtype: int64

# %% [markdown]
# Столбцы `critic_score` и `user_score`:

# %% [markdown]
# Остались столбцы с рейтингом критиков и игроков. Эти значения часто получаются не исходя из качества игры, а также из множества факторов, зачастую даже просто от даты выхода игры, изначального наличия багов и даже наличия определенного языка.
# Поэтому заполнить их можно, например, подтягивая данные с сайта Metacritic.
#
# Так как какое-либо заполнение пропусков может повлиять на результат анализа в плане подсчета среднего, заполнять пропуски не будем.

# %%
print(df_game['critic_score'].value_counts())
print(df_game['critic_score'].unique())
# Out:
# 70.0    256
# 71.0    254
# 75.0    245
# 78.0    240
# 73.0    238
# 80.0    237
# 76.0    235
# 72.0    226
# 74.0    226
# 77.0    225
# 68.0    219
# 81.0    218
# 79.0    218
# 69.0    215
# 82.0    208
# 83.0    206
# 66.0    203
# 65.0    192
# 84.0    183
# 67.0    182
# 63.0    178
# 62.0    170
# 64.0    169
# 61.0    165
# 59.0    157
# 60.0    156
# 85.0    151
# 58.0    151
# 86.0    137
# 57.0    132
# 87.0    118
# 88.0    116
# 56.0    113
# 55.0    110
# 89.0    105
# 53.0    103
# 54.0    103
# 51.0     90
# 49.0     86
# 50.0     79
# 90.0     76
# 52.0     73
# 91.0     70
# 48.0     67
# 47.0     66
# 46.0     56
# 43.0     54
# 92.0     54
# 44.0     50
# 45.0     47
# 93.0     47
# 39.0     39
# 94.0     37
# 42.0     37
# 38.0     34
# 41.0     29
# 37.0     28
# 35.0     27
# 36.0     26
# 40.0     26
# 33.0     22
# 96.0     18
# 95.0     16
# 32.0     15
# 26.0     12
# 30.0     12
# 28.0     11
# 97.0     11
# 34.0     10
# 31.0      9
# 27.0      8
# ...

# %%
print(df_game['user_score'].value_counts())
print(df_game['user_score'].unique())
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
# 8.5     253
# 7.5     251
# 7.9     249
# 8.1     244
# 7.7     240
# 7.3     236
# 8.4     223
# 7       220
# 7.6     220
# 7.4     215
# 8.6     211
# 6.8     197
# 8.7     188
# 8.8     186
# 7.1     180
# 7.2     167
# 8.9     153
# 6.6     148
# 6.9     143
# 6.3     138
# 6.7     128
# 6       127
# 6.5     125
# 9       120
# 6.2     113
# 6.4     107
# 5.8      97
# 9.1      90
# 6.1      84
# 5.7      78
# 5.9      77
# 5.6      72
# 5.4      72
# 5.5      71
# 5.3      70
# 5        64
# 5.2      57
# 4.8      49
# 5.1      44
# 9.2      43
# 4.9      40
# 4.6      37
# 4.3      37
# 4.5      34
# 4.1      33
# 4.4      33
# 9.3      31
# 4.2      28
# 3.8      28
# 4        27
# 3.5      26
# 4.7      24
# 2.8      24
# 3.4      23
# 3.1      23
# 3        21
# 3.6      20
# 3.7      19
# 3.3      15
# 3.9      13
# 3.2      13
# 2.5      12
# 2        11
# 2.4      11
# 9.4      11
# 1.7       9
# ...

# %% [markdown]
# Самым популярным значением пользовательской оценки оказалось значние tbd - To Be Determined, то есть "Будет определено", значит это тоже пропуск.
# Можно заменить это значение на NaN, чтобы столбец был типа float и мы могли подсчитать, например, среднее.

# %%
df_game['user_score'] = df_game['user_score'].replace({'tbd':np.NaN})

# %%
display(df_game.isna().sum())
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         9123
# rating                0
# dtype: int64

# %% [markdown]
# Вернемся к замене типов данных. Так как остались пропуски в столбце с оценкой критиков, не получится изменить тип данных.
#
#
# Заменим тип данных в столбцах с годом релиза (установим целочисленный) и оценкой пользователей (сделаем с плавающей точкой):

# %%
df_game['year_of_release'] = df_game['year_of_release'].astype('int')

df_game['user_score'] = df_game['user_score'].astype('float')

# %% [markdown]
# Также удалим дубликаты, если они есть:

# %%
df_game.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Добавим столбец с суммой продаж во всех регионах:

# %%
df_game['total_sales'] = df_game['na_sales'] + df_game['eu_sales'] + df_game['jp_sales'] + df_game['other_sales']
df_game.head(7)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
# 5                    Tetris       GB             1989        Puzzle     23.20
# 6     New Super Mario Bros.       DS             2006      Platform     11.28
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN     -1
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# ...

# %%
df_game.filter(like='sales').sum(axis=1)
# Out:
# 0        165.08
# 1         80.48
# 2         71.04
# 3         65.54
# 4         62.76
# 5         60.52
# 6         59.60
# 7         57.82
# 8         56.64
# 9         56.62
# 10        49.34
# 11        46.42
# 12        46.18
# 13        45.40
# 14        43.64
# 15        43.60
# 16        42.10
# 17        41.62
# 18        41.24
# 19        40.28
# 20        36.48
# 21        36.28
# 22        34.56
# 23        32.54
# 24        32.30
# 25        31.68
# 26        30.56
# 27        30.26
# 28        29.94
# 29        29.46
# 30        29.28
# 31        29.26
# 32        29.24
# 33        29.20
# 34        27.58
# 35        27.36
# 36        26.94
# 37        26.66
# 38        26.20
# 39        25.68
# 40        25.30
# 41        25.26
# 42        25.24
# 43        24.28
# 44        24.24
# 45        23.80
# 46        23.54
# 47        23.36
# 48        23.30
# 49        22.70
# 50        22.36
# 51        22.00
# 52        21.90
# 53        21.62
# 54        21.40
# ...

# %%
df_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 12 columns):
# name               16713 non-null object
# platform           16713 non-null object
# year_of_release    16713 non-null int64
# genre              16713 non-null object
# na_sales           16713 non-null float64
# eu_sales           16713 non-null float64
# jp_sales           16713 non-null float64
# other_sales        16713 non-null float64
# critic_score       8137 non-null float64
# user_score         7590 non-null float64
# rating             16713 non-null object
# total_sales        16713 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Вывод

# %% [markdown]
# В данном пункте:
# * Были заменены названия столбцов (приведены к нижнему регистру);
# * Изучены пропуски, заменены в столбцах 'year_of_release' и 'user_score';
# * Удалены 2 строки с пропуском в названии игры;
# * Заменены типы данных столбцов 'year_of_release' и 'user_score';
# * Добавлен столбец с суммарными продажами во всех регионах.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Релизы игр по годам

# %% [markdown]
# Посмотрим, сколько игр выпускалось в разные годы и ответим на вопрос, важны ли данные за все периоды.

# %%
(
    df_game.query('year_of_release > 0')
    .pivot_table(index='year_of_release', values='name', aggfunc='count')
    .plot(kind="bar",grid=False, figsize=(17, 10))
)
plt.title('График количества релизов игр в разные годы')
# Out:
# Text(0.5, 1.0, 'График количества релизов игр в разные годы')

# %% [markdown]
# Рост количества выпускаемых игр начался с середины 90-х, когда игровые приставки и персональные компьютеры стали более доступными.
#
# Пик в 2008-2009 годах связан с тем, что существовало много компаний, которые выпускали игры среднего сегмента, позже компании были поглощены более крупными разработчиками и рынок перешел к выпуску игр AAA-сегмента, то есть количество переросло в качество.
#
#
# Игры, выпускаемые до 1994 менее важны еще и потому, что были популярны игровые автоматы и многие играли не дома и не видели смысла переплачивать за домашние приставки.
# Sega Mega Drive появилась в 1988, но у нас в России мы играли в нее как раз с 1995 года.

# %% [markdown]
# ### Продажи по платформам

# %% [markdown]
# Теперь посмотрим, как менялись продажи по платформам.
#
# Выберем платформы с наибольшими суммарными продажами и построим распределение по годам.
#
# Ответим на вопрос, за какой характерный срок появляются новые и исчезают старые платформы.

# %% [markdown]
# Посмотрим, какая на какой платформе было больше всего суммарных продаж, для этого сделаем сводную таблицу и посмотрим на первые 10 платформ:

# %%
df_platform = (df_game
               .pivot_table(index='platform', values='total_sales', aggfunc='sum')
               .sort_values(by='total_sales', ascending=False)
              )

# %%
df_platform_top10 = df_platform[:10]
df_platform_top10
# Out:
#           total_sales
# platform
# PS2           1255.77
# X360           971.42
# PS3            939.65
# Wii            907.51
# DS             806.12
# PS             730.86
# GBA            317.85
# PS4            314.14
# PSP            294.05
# PC             259.52

# %% [markdown]
# Проверим, правильно ли посчитались общие продажи, например для PS:

# %%
(df_game.query('platform == "PS"')['na_sales'].sum() +
 df_game.query('platform == "PS"')['eu_sales'].sum() +
 df_game.query('platform == "PS"')['jp_sales'].sum() +
 df_game.query('platform == "PS"')['other_sales'].sum())
# Out:
# 730.86

# %% [markdown]
# Теперь для 10 платформ посчитаем сумму продаж по годам, сначала создадим таблицу для всех платформ с продажами с 1994 года, а потом проверим, входят ли эти платформы в индекс таблицы с топ-продажами.

# %%
df_platform_year=(df_game
 .query('year_of_release >= 1994')
 .pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum'))

# %%
for platform in df_platform_year.columns:
    if platform not in df_platform_top10.index:
        df_platform_year.drop(platform, axis=1, inplace=True)
df_platform_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 1994 to 2016
# Data columns (total 10 columns):
# DS      10 non-null float64
# GBA     8 non-null float64
# PC      23 non-null float64
# PS      10 non-null float64
# PS2     12 non-null float64
# PS3     11 non-null float64
# PS4     4 non-null float64
# PSP     12 non-null float64
# Wii     11 non-null float64
# X360    12 non-null float64
# dtypes: float64(10)
# memory usage: 2.0 KB

# %%
df_platform_year.fillna(0, inplace=True)

# %%
df_platform_year
# Out:
# platform             DS    GBA     PC      PS     PS2     PS3     PS4    PSP  \
# year_of_release
# 1994               0.00   0.00  12.87    6.03    0.00    0.00    0.00   0.00
# 1995               0.00   0.00   4.22   35.96    0.00    0.00    0.00   0.00
# 1996               0.00   0.00  10.58   94.70    0.00    0.00    0.00   0.00
# 1997               0.00   0.00  11.27  136.17    0.00    0.00    0.00   0.00
# 1998               0.00   0.00   3.26  169.49    0.00    0.00    0.00   0.00
# 1999               0.00   0.00   4.74  144.53    0.00    0.00    0.00   0.00
# 2000               0.00   0.07   4.66   96.37   39.17    0.00    0.00   0.00
# 2001               0.00  61.53   5.47   35.59  166.43    0.00    0.00   0.00
# 2002               0.00  74.16   8.57    6.67  205.38    0.00    0.00   0.00
# 2003               0.00  56.67   8.84    2.07  184.31    0.00    0.00   0.00
# 2004              17.27  77.91  10.39    0.00  211.81    0.00    0.00   7.06
# ...

# %% [markdown]
# Отобразим данную таблицу на графике:

# %%
df_platform_year.plot.barh(stacked=True, alpha=0.6, figsize=(18, 15))
plt.title('Топ-10 платформ с продажами с 1994 по 2016 года')
# Out:
# Text(0.5, 1.0, 'Топ-10 платформ с продажами с 1994 по 2016 года')

# %% [markdown]
# Судя по количеству продаж, платформы актуальны в среднем 8-12 лет.
#
# PC платформа всех времен, всегда актуальна!
#
# На примере выпуска PlayStation, в среднем, после выхода следующего поколения предыдущее актуально еще 3-5 лет, это тоже можно учитывать, рассматривая платформы для выхода игр на текущи момент.

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(figsize=(16, 9), dpi=75)
sns.despine(left=True, ax=ax)
sns.heatmap(df_platform_year.T, annot=True, fmt='.0f', ax=ax, cmap='Oranges');

# %% [markdown]
# В более наглядном формате отображаются периода жизни платформ

# %% [markdown]
# ### Актуальный период

# %% [markdown]
# Для прогноза потенциально прибыльных платформ на 2017 год возьмем период с 2013 года - дата выхода PlayStation 4 и настоящее начало 8 поколения игровых систем (8 поколение началось с 2011 года с выхода Nintendo 3DS и PlayStation Vita, но это все же портативные приставки, которые менее мощные), также после 2011 года наблюдается спад количества выпущенных игр.

# %%
df_game_actual = df_game.query('year_of_release >= 2013')

# %%
df_game_actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2233 entries, 16 to 16714
# Data columns (total 12 columns):
# name               2233 non-null object
# platform           2233 non-null object
# year_of_release    2233 non-null int64
# genre              2233 non-null object
# na_sales           2233 non-null float64
# eu_sales           2233 non-null float64
# jp_sales           2233 non-null float64
# other_sales        2233 non-null float64
# critic_score       991 non-null float64
# user_score         1192 non-null float64
# rating             2233 non-null object
# total_sales        2233 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 226.8+ KB

# %%
df_game_actual.head()
# Out:
#                          name platform  year_of_release         genre  \
# 16         Grand Theft Auto V      PS3             2013        Action
# 23         Grand Theft Auto V     X360             2013        Action
# 31  Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33        Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 42         Grand Theft Auto V      PS4             2014        Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 31      6.03      5.86      0.36         2.38           NaN         NaN
# 33      5.28      4.19      4.35         0.78           NaN         NaN
# 42      3.96      6.31      0.38         1.97          97.0         8.3
#
#    rating  total_sales
# 16      M        21.05
# 23      M        16.27
# 31     -1        14.63
# ...

# %% [markdown]
# ### Потенциально прибыльные платформы

# %% [markdown]
# Найдем актуальные платформы (на которых выпускают игры с 2013-2016 года), подсчитаем количество проданных игр и вычислим самые прибыльные.

# %%
df_game_actual_top10 = (df_game_actual
                        .pivot_table(index=['platform','year_of_release'], values='total_sales', aggfunc='sum')
                       )

# %%
df_game_actual_top10
# Out:
#                           total_sales
# platform year_of_release
# 3DS      2013                   56.57
#          2014                   43.76
#          2015                   27.78
#          2016                   15.14
# DS       2013                    1.54
# PC       2013                   12.38
#          2014                   13.28
#          2015                    8.52
#          2016                    5.25
# PS3      2013                  113.25
#          2014                   47.76
#          2015                   16.82
#          2016                    3.60
# PS4      2013                   25.99
#          2014                  100.00
#          2015                  118.90
#          2016                   69.25
# PSP      2013                    3.14
#          2014                    0.24
#          2015                    0.12
# PSV      2013                   10.59
#          2014                   11.90
#          2015                    6.25
# ...

# %%
df_game_actual_top10_all = (df_game_actual_top10
 .pivot_table(index='platform', values='total_sales', aggfunc='sum')
 .sort_values('total_sales', ascending=False).reset_index()
)
display(df_game_actual_top10_all)
# Out:
#    platform  total_sales
# 0       PS4       314.14
# 1       PS3       181.43
# 2      XOne       159.32
# 3       3DS       143.25
# 4      X360       136.80
# 5      WiiU        64.63
# 6        PC        39.43
# 7       PSV        32.99
# 8       Wii        13.66
# 9       PSP         3.50
# 10       DS         1.54

# %% [markdown]
# Топ-5 платформ по продажам: PS4, PS3, XOne, 3DS, X360.
#
# PlayStation 4 и Xbox One на конец 2016 года являются самыми производительными игровыми платформами, на них будут самые высокие продажи в 2017 году.
# 3DS, WiiU и PSV можно рассматривать, но WiiU и PSV являются не очень популярными платвормами сами по себе, а на 2017 у Nintendo запланирован выход новой портативной (гибридной) консоли Nintendo Switch, но 3DS, в принципе, еще несколько лет будет актуальной.
# PC всегда останется актуальной платформой, поэтому в долгосрочной перспективе можно рассматривать эту платформу как прибыльную.
#
#
# На приставках прошлого поколения - PS3, X360, Wii, PSP, DS падают продажи с каждым годом, поэтому их точно не стоит рассматривать как потенциально прибыльные.
#
# В итоге, PlayStation 4 (как самая продаваемая), Xbox One (есть обратная совместимость со всеми остальными приставками Xbox), 3DS (как самая популярная портативная консоль), WiiU (как предшественник Nintendo Switch) и PC (как платформа на все времена) являются потенциально прибыльными платформами.

# %% [markdown]
# ###  Глобальные продажи игр в разбивке по платформам

# %% [markdown]
# Построим график «ящик с усами» по глобальным продажам игр в разбивке по платформам:

# %%
sns.catplot(x="platform", y='total_sales', kind='box', data=df_game, height=7, aspect=2, palette="pastel")

plt.ylim(0, 5)
plt.title('Все платформы')
# Out:
# Text(0.5, 1, 'Все платформы')

# %%
sns.catplot(x="platform", y='total_sales', kind='box', data=df_game_actual, height=7, aspect=2, palette="pastel")

plt.ylim(0, 3)
plt.title('Топ платформ по продажам с 2013 по 2016 годы')
# Out:
# Text(0.5, 1, 'Топ платформ по продажам с 2013 по 2016 годы')

# %% [markdown]
# Топ-платформ по продажам (слева-направо в порядке убывания):

# %%
sns.catplot(x="platform", y='total_sales', kind='box', data=df_game_actual, height=7, aspect=2, palette="pastel", order=list(df_game_actual_top10_all['platform']))

plt.ylim(0, 3)
plt.title('Топ платформ по продажам с 2013 по 2016 годы')
# Out:
# Text(0.5, 1, 'Топ платформ по продажам с 2013 по 2016 годы')

# %% [markdown]
# Выведем более подробный результат по потенциально прибыльным платформам:

# %%
for name_platform in ['PS4','XOne','3DS','WiiU','PC']:
    print(name_platform, 'Данные по выручке с 2013 года:')
    display(df_game_actual.query('platform == @name_platform')['total_sales'].describe())
    print()
print('Данные по выручке с 2013 года по всем платформам:')    
display(df_game_actual['total_sales'].describe())
# Out:
# PS4 Данные по выручке с 2013 года:
# count    392.000000
# mean       0.801378
# std        1.609456
# min        0.010000
# 25%        0.060000
# 50%        0.200000
# 75%        0.730000
# max       14.630000
# Name: total_sales, dtype: float64
# XOne Данные по выручке с 2013 года:
# count    247.000000
# mean       0.645020
# std        1.036139
# min        0.010000
# 25%        0.060000
# 50%        0.220000
# 75%        0.685000
# max        7.390000
# Name: total_sales, dtype: float64
# 3DS Данные по выручке с 2013 года:
# count    303.000000
# mean       0.472772
# std        1.381347
# min        0.010000
# 25%        0.040000
# 50%        0.090000
# 75%        0.280000
# max       14.600000
# Name: total_sales, dtype: float64
# WiiU Данные по выручке с 2013 года:
# count    115.000000
# mean       0.562000
# std        1.038778
# min        0.010000
# 25%        0.060000
# 50%        0.200000
# 75%        0.595000
# max        7.090000
# Name: total_sales, dtype: float64
# ...

# %% [markdown]
# * В период с 2013 по 2016 годы средняя выручка по всем актуальным платформам составила 488 тысяч, 75% игр заработали 400 тысяч. Максимальное значение 21 миллион.
# * В период с 2013 по 2016 годы средняя выручка на платформе PS4 составила 801 тысячу, 75% игр заработали 730 тысяч. Максимальное значение 14,63 миллиона.
# * В период с 2013 по 2016 годы средняя выручка на платформе XOne составила 645 тысяч, 75% игр заработали 685 тысяч. Максимальное значение 7,39 миллиона.
# * В период с 2013 по 2016 годы средняя выручка на платформе 3DS составила 472,2 тысячи, 75% игр заработали 280 тысяч. Максимальное значение 14,6 миллиона.
# * В период с 2013 по 2016 годы средняя выручка на платформе WiiU составила 562 тысячи, 75% игр заработали 595 тысяч. Максимальное значение 7,09 миллиона.
# * В период с 2013 по 2016 годы средняя выручка на платформе PC составила 208,6 тысяч, 75% игр заработали 230 тысяч. Максимальное значение 3,05 миллиона.

# %% [markdown]
# ### Влияние на продажи отзывов пользователей и критиков

# %% [markdown]
# Построим срез для платформы PS4 по продажам и отзывам:

# %%
df_PS4 = df_game.query('platform == "PS4"').loc[:,['total_sales', 'critic_score', 'user_score']]
display(df_PS4.head(7))
# Out:
#      total_sales  critic_score  user_score
# 31         14.63           NaN         NaN
# 42         12.62          97.0         8.3
# 77          8.58          82.0         4.3
# 87          7.98           NaN         NaN
# 92          7.66          83.0         5.7
# 94          7.60          85.0         5.0
# 105         7.17          87.0         6.5

# %% [markdown]
# Посмотрим, есть ли корреляции между продажами и отзывами:

# %%
display(df_PS4.corr())
# Out:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.406568   -0.031957
# critic_score     0.406568      1.000000    0.557654
# user_score      -0.031957      0.557654    1.000000

# %%
pd.plotting.scatter_matrix(df_PS4, alpha=0.6, figsize=(13, 13));

# %% [markdown]
# Исходя из рассчитанных корреляций и построенного графика, можно сделать вывод, что на продажи влияют рейтинги критиков. А также рейтинги критиков влияют на рейтинги игроков.

# %% [markdown]
# Теперь соотнесем найденные корреляции с остальными платформами (посмотрим на платформы по топам продаж):

# %%
print(f'Корреляция между продажами и оценками критиков и игроков на платформе PS3:')
display(df_game.query('platform == "PS3"').loc[:,['total_sales', 'critic_score', 'user_score']].corr())
pd.plotting.scatter_matrix(df_game.query('platform == "PS3"').loc[:,['total_sales', 'critic_score', 'user_score']], alpha=0.6, figsize=(13, 13));
# Out:
# Корреляция между продажами и оценками критиков и игроков на платформе PS3:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.432432    0.126691
# critic_score     0.432432      1.000000    0.629005
# user_score       0.126691      0.629005    1.000000

# %%
print(f'Корреляция между продажами и оценками критиков и игроков на платформе XOne:')
display(df_game.query('platform == "XOne"').loc[:,['total_sales', 'critic_score', 'user_score']].corr())
pd.plotting.scatter_matrix(df_game.query('platform == "XOne"').loc[:,['total_sales', 'critic_score', 'user_score']], alpha=0.6, figsize=(13, 13));
# Out:
# Корреляция между продажами и оценками критиков и игроков на платформе XOne:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.416998   -0.068925
# critic_score     0.416998      1.000000    0.472462
# user_score      -0.068925      0.472462    1.000000

# %%
print(f'Корреляция между продажами и оценками критиков и игроков на платформе 3DS:')
display(df_game.query('platform == "3DS"').loc[:,['total_sales', 'critic_score', 'user_score']].corr())
pd.plotting.scatter_matrix(df_game.query('platform == "3DS"').loc[:,['total_sales', 'critic_score', 'user_score']], alpha=0.6, figsize=(13, 13));
# Out:
# Корреляция между продажами и оценками критиков и игроков на платформе 3DS:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.349401    0.224808
# critic_score     0.349401      1.000000    0.744168
# user_score       0.224808      0.744168    1.000000

# %%
print(f'Корреляция между продажами и оценками критиков и игроков на платформе X360:')
display(df_game.query('platform == "X360"').loc[:,['total_sales', 'critic_score', 'user_score']].corr())
pd.plotting.scatter_matrix(df_game.query('platform == "X360"').loc[:,['total_sales', 'critic_score', 'user_score']], alpha=0.6, figsize=(13, 13));
# Out:
# Корреляция между продажами и оценками критиков и игроков на платформе X360:
#               total_sales  critic_score  user_score
# total_sales      1.000000      0.393736    0.114459
# critic_score     0.393736      1.000000    0.618101
# user_score       0.114459      0.618101    1.000000

# %%
#for name_platform in ['PS3','XOne','3DS','X360']:
    #print(f'Корреляция между продажами и оценками критиков и игроков на платформе {name_platform}:')
    #display(df_game.query('platform == @name_platform').loc[:,['total_sales', 'critic_score', 'user_score']].corr())
    #print()
    #pd.plotting.scatter_matrix(df_game.query('platform == @name_platform').loc[:,['total_sales', 'critic_score', 'user_score']], alpha=0.6, figsize=(13, 13))

# %% [markdown]
# XOne имеет такую же корреляцию по рейтингам, как и PS4, это актуальные (на 2016 год) платформы, где вышло еще не так много лучших игр поколения.
#
# PS3 более старая платформа, поэтому рейтинги игроков уже сформированыи немного влияют на общие продажи, также и у 3DS и Xbox360, вышло уже много игр, проставлено больше оценок, а также чаще покупают более "нашумевшие" игры, у которых больше оценок критиков и больше продаж, так как нужно как-то выбирать из огромного количества вышедших игр.

# %% [markdown]
# ###  Самые прибыльные жанры

# %% [markdown]
# Посмотрим, какие жанры популярны с 2013 года:

# %%
df_genre = (df_game_actual
            .pivot_table(index='genre', values='total_sales', aggfunc='sum')
            .sort_values('total_sales', ascending=False)
           )

# %%
df_genre
# Out:
#               total_sales
# genre
# Action             321.87
# Shooter            232.98
# Sports             150.65
# Role-Playing       145.89
# Misc                62.82
# Platform            42.63
# Racing              39.89
# Fighting            35.31
# Adventure           23.64
# Simulation          21.76
# Strategy            10.08
# Puzzle               3.17

# %%
sns.catplot(x='genre', y='total_sales', kind='box', data=df_game_actual, height=7, aspect=2, palette="pastel")

plt.ylim(0, 3.5)
plt.title('Топ жанров по продажам с 2013 по 2016 годы')
# Out:
# Text(0.5, 1, 'Топ жанров по продажам с 2013 по 2016 годы')

# %% [markdown]
# Сравним, как менялись заинтересованности игроков со временем:

# %%
(df_game.query('1970<=year_of_release<=2013')
        .pivot_table(index='genre', values='total_sales', aggfunc='sum')
        .sort_values('total_sales', ascending=False)
           )
# Out:
#               total_sales
# genre
# Action            1517.16
# Sports            1200.19
# Shooter            870.42
# Role-Playing       829.64
# Platform           807.46
# Misc               752.74
# Racing             695.97
# Fighting           414.44
# Simulation         374.83
# Puzzle             237.68
# Adventure          215.78
# Strategy           168.61

# %% [markdown]
# Жанр Shooter - самый популярный, после него идут Action, Sports и Role-Playing. В приниципе, эти жанры как были популярны до 2013, так и остались, навряд ли что-то изменится.
#
# Shooter занимает топ, так как это обычно командные игры, также и в спортивные можно играть с друзьями.
#
#
# А вот симуляторы, паззлы стали еще менее популярными жанрами. Стратегии так и вовсе всегда были не очень популярным жанром.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Просмотрев актуальные на 2013-2016 год платформы, жанры, можно сделать следующий вывод:
#
# В 2017 году прибыльными платформами будут PS4 и XOne, а также Nintendo Switch (как новая интересная платформа, так как заменит 3DS и WiiU) а игра должна быть жанра Action или Shooter.

# %% [markdown]
# ## Портрет пользователя каждого региона

# %% [markdown]
# ###  Самые популярные платформы для каждого региона

# %% [markdown]
# Составим таблицу и построим график для популярных платформ с 2013 года в зависимости от региона:

# %%
df_game_region = (df_game_actual
                  .pivot_table(index='platform',values=['na_sales','eu_sales','jp_sales'], aggfunc='sum')
                  .sort_values(by='eu_sales',ascending=False))
df_game_region = df_game_region[:8]

# %%
df_game_region
# Out:
#           eu_sales  jp_sales  na_sales
# platform
# PS4         141.09     15.96    108.74
# PS3          67.81     23.35     63.50
# XOne         51.59      0.34     93.12
# X360         42.52      0.51     81.66
# 3DS          30.96     67.81     38.20
# PC           25.36      0.00     11.11
# WiiU         19.85     10.88     29.21
# PSV           6.10     18.59      5.04

# %%
df_game_region.plot.bar(grid=True, figsize=(17, 10), color=['#ffd1dc','#08e8de','#a2a2d0'])
plt.title('Самые популярные платформы в зависимости от региона с 2013 по 2016 годы')
# Out:
# Text(0.5, 1.0, 'Самые популярные платформы в зависимости от региона с 2013 по 2016 годы')

# %% [markdown]
# Данные отсортированы для Европейского региона и сразу видно, что в Японии все наоборот.
#
# В Японии больше любят портативные консоли: 3DS, PSV (все-таки они и придумали Game and Watch, чтобы в метро играть) и совсем не любят американский XOne и Xbox360. Про консоли от Sony тоже не забывают, нужна же и домашняя консоль, ведь PC не очень растпространены в Японии (вроде дешевле ноутбук купить, чем отдельные комплектующие, но кто любить играть в актуальные игры на ноутбуках?).
#
# В Европе больше предпочитают PlayStation и вообще домашние консоли.
#
# А в Америке предпочтение отдают актуальным консолям PS4 и XOne и вообще консолям от Microsoft.

# %% [markdown]
# ###  Самые популярные жанры для каждого региона

# %% [markdown]
# Посмотрим на каждый регион в отдельности, а также построим графики для популярных жанров:

# %%
# США после 2013 года и до

(df_game_actual
              .pivot_table(index='genre',values='na_sales', aggfunc='sum')
              .sort_values(by='na_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#a2a2d0'))
plt.title('График популярности игровых жанров в Северной Америке с 2013-2016 годы')

(df_game.query('1970<=year_of_release<=2013')
              .pivot_table(index='genre',values='na_sales', aggfunc='sum')
              .sort_values(by='na_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#a2a2d0'))
plt.title('График популярности игровых жанров в Северной Америке до 2013 года')
# Out:
# Text(0.5, 1.0, 'График популярности игровых жанров в Северной Америке до 2013 года')

# %% [markdown]
# Жанр Action как был самым популярным, так и остался. А вот Shooter стал намного популярнее, чем Sports.
# Role Playing вообще не было в топ-5 до 2013 года, но теперь это 4 место по популярности.
# Misc как был на 5 месте, так и остался.

# %%
# Европа после 2013 года и до

(df_game_actual
              .pivot_table(index='genre',values='eu_sales', aggfunc='sum')
              .sort_values(by='eu_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#ffd1dc'))
plt.title('График популярности игровых жанров в Европе с 2013-2016 годы')

(df_game.query('1970<=year_of_release<=2013')
              .pivot_table(index='genre',values='eu_sales', aggfunc='sum')
              .sort_values(by='eu_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#ffd1dc'))
plt.title('График популярности игровых жанров в Европе до 2013 года')
# Out:
# Text(0.5, 1.0, 'График популярности игровых жанров в Европе до 2013 года')

# %% [markdown]
# 1-4 места идентичны Североамериканским, но 5 место после 2013 года занял жанр Racing, который менее популярен в Америке.
#
# А вот до 2013 года отличается только 4 место, которое занимал Racing (платформеров вообще нет в топ-5, как в Америке).

# %%
# Япония после 2013 года и до

(df_game_actual
              .pivot_table(index='genre',values='jp_sales', aggfunc='sum')
              .sort_values(by='jp_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#08e8de'))
plt.title('График популярности игровых жанров в Японии с 2013-2016 годы')

(df_game.query('1970<=year_of_release<=2013')
              .pivot_table(index='genre',values='jp_sales', aggfunc='sum')
              .sort_values(by='jp_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#08e8de'))
plt.title('График популярности игровых жанров в Японии до 2013 года')
# Out:
# Text(0.5, 1.0, 'График популярности игровых жанров в Японии до 2013 года')

# %% [markdown]
# Популярны соверешнно иные жанры, нежели чем в Европе и Америке.
# Role Playing не изменил своей абсолютной популярности, но Action стал намного популярнее и поднялся до 2 места. Спортивные игры утратили свою популярноть и со 2 места вообще ушли из топ-5.
# Misc стал популярнее, но разрыв со 2 местом огромный.
# Файтинг игры и Шутеры заменили собой спортивные и платформеры.

# %% [markdown]
# ### Влияние рейтинга ESRB на продажи в отдельном регионе

# %% [markdown]
# Вспомним категории рейтинга ESRB:
#
# * «EC» («Early childhood») — «Для детей младшего возраста»
# * «E» («Everyone») — «Для всех»
# * «E10+» («Everyone 10 and older») — «Для всех от 10 лет и старше»
# * «T» («Teen») — «Подросткам» - от 13 лет
# * «M» («Mature») — «Для взрослых» - от 17 лет
# * «AO» («Adults Only 18+») — «Только для взрослых»
# * «RP» («Rating Pending») — «Рейтинг ожидается»

# %%
print(df_game['rating'].unique())
# Out:
# ['E' -1 'M' 'T' 'E10+' 'AO' 'EC' 'RP']

# %% [markdown]
# Построим графики по популярности рейтингов в каждом регионе по отдельности.

# %%
# США после 2013 года 

(df_game_actual[df_game_actual['rating']!=-1]
              .pivot_table(index='rating',values='na_sales', aggfunc='sum')
              .sort_values(by='na_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#a2a2d0'))
plt.title('График популярности рейтингов игр в Северной Америке с 2013-2016 годы')
# Out:
# Text(0.5, 1.0, 'График популярности рейтингов игр в Северной Америке с 2013-2016 годы')

# %%
# Европа после 2013 года 

(df_game_actual[df_game_actual['rating']!=-1]
              .pivot_table(index='rating',values='eu_sales', aggfunc='sum')
              .sort_values(by='eu_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#ffd1dc'))
plt.title('График популярности рейтингов игр в Европе с 2013-2016 годы')
# Out:
# Text(0.5, 1.0, 'График популярности рейтингов игр в Европе с 2013-2016 годы')

# %%
# Япония после 2013 года 

(df_game_actual[df_game_actual['rating']!=-1]
              .pivot_table(index='rating',values='jp_sales', aggfunc='sum')
              .sort_values(by='jp_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#08e8de'))
plt.title('График популярности рейтингов игр в Японии с 2013-2016 годы')
# Out:
# Text(0.5, 1.0, 'График популярности рейтингов игр в Японии с 2013-2016 годы')

# %% [markdown]
# В Америке более популярен рейтинг «M», но места распределены идентично.
#
# В Японии опять все по-другому. На 1-м месте рейтинг «T», а рейтинги «E» и «M» имеют почти одинаковые показатели.

# %% [markdown]
# Графики с учетом отсутствующего рейтинга:

# %%
# США после 2013 года 

(df_game_actual
              .pivot_table(index='rating',values='na_sales', aggfunc='sum')
              .sort_values(by='na_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#a2a2d0'))
plt.title('График популярности рейтингов игр в Северной Америке с 2013-2016 годы')
# Out:
# Text(0.5, 1.0, 'График популярности рейтингов игр в Северной Америке с 2013-2016 годы')

# %%
# Европа после 2013 года 

(df_game_actual
              .pivot_table(index='rating',values='eu_sales', aggfunc='sum')
              .sort_values(by='eu_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#ffd1dc'))
plt.title('График популярности рейтингов игр в Европе с 2013-2016 годы')
# Out:
# Text(0.5, 1.0, 'График популярности рейтингов игр в Европе с 2013-2016 годы')

# %%
# Япония после 2013 года 

(df_game_actual
              .pivot_table(index='rating',values='jp_sales', aggfunc='sum')
              .sort_values(by='jp_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#08e8de'))
plt.title('График популярности рейтингов игр в Японии с 2013-2016 годы')
# Out:
# Text(0.5, 1.0, 'График популярности рейтингов игр в Японии с 2013-2016 годы')

# %%
# Япония за все время

(df_game
              .pivot_table(index='rating',values='jp_sales', aggfunc='sum')
              .sort_values(by='jp_sales',ascending=False)[:5].plot(kind="bar",grid=True, figsize=(7, 5), color='#08e8de'))
plt.title('График популярности рейтингов игр в Японии')
# Out:
# Text(0.5, 1.0, 'График популярности рейтингов игр в Японии')

# %% [markdown]
# ### Вывод

# %% [markdown]
# Япония - отличный от Европы и Америки регион. Рейтинг игр - «T» - для детей от 13 лет, платформа 3DS и Role Playing жанр игр.
#
# В Европе и Америке больше играют в игры для тех, кому должно быть больше 17 лет на PS4 или XOne и это будет Action-игра.

# %% [markdown]
# Самым часто-встречающимся рейтингом в Японии оказалось отсутствие рейтинга, что не удивительно, ведь ESRB - американская система.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Необходимо проверить 2 гипотезы:
#
# 1. Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# 2. Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# Рассчитаем средние пользовательские оценки для платформ Xbox One и PC и построим графики:

# %%
display(df_game_actual.query('platform == "XOne"')['user_score'].describe())
df_game_actual.query('platform == "XOne"')['user_score'].plot(kind='hist',grid=True, figsize=(7, 5), color='#007fff')
plt.title('График пользовательского рейтинга платформы Xbox One')
# '#007fff' лазурный
# Out:
# count    182.000000
# mean       6.521429
# std        1.380941
# min        1.600000
# 25%        5.800000
# 50%        6.800000
# 75%        7.500000
# max        9.200000
# Name: user_score, dtype: float64
# Text(0.5, 1.0, 'График пользовательского рейтинга платформы Xbox One')

# %%
display(df_game_actual.query('platform == "PC"')['user_score'].describe())
df_game_actual.query('platform == "PC"')['user_score'].plot(kind='hist',grid=True, figsize=(7, 5), color='#007fff')
plt.title('График пользовательского рейтинга платформы PC')
# Out:
# count    155.000000
# mean       6.269677
# std        1.742381
# min        1.400000
# 25%        5.300000
# 50%        6.800000
# 75%        7.600000
# max        9.300000
# Name: user_score, dtype: float64
# Text(0.5, 1.0, 'График пользовательского рейтинга платформы PC')

# %% [markdown]
# Проверка гипотез начинается с формулировки нулевой гипотезы H₀:
#
# **H₀** = Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#
# Исходя из H₀ формулируется альтернативная гипотеза H₁. Это утверждение, которое принимается верным, если отбрасывается H₀:
#
# **H₁** = Средние пользовательские рейтинги платформ Xbox One и PC различны.

# %% [markdown]
# Нам необходимо сравнить 2 генеральные совокупности, поэтому воспользуемся методом scipy.stats.ttest_ind (наши генеральные совокупности не зависят друг от друга и средние нормально распределены), которому передадим таблицы с разными платформами:

# %%
alpha = .01 # критический уровень статистической значимости

results = st.ttest_ind(
    df_game_actual.query('platform == "XOne"')['user_score'].dropna(), 
    df_game_actual.query('platform == "PC"')['user_score'].dropna())

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 0.14012658403611647
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Исходя из графиков и расчетов, а также проверки гипотез, можно сказать, что средние пользовательские рейтинги платформ Xbox One (6,52) и PC (6,27) одинаковые.

# %% [markdown]
# Расчитаем средние пользовательские оценки для жанров Action и Sports и построим графики:

# %%
display(df_game_actual.query('genre == "Action"')['user_score'].describe())
df_game_actual.query('genre == "Action"')['user_score'].plot(kind='hist',grid=True, figsize=(7, 5), color='#ff8800')
plt.title('График пользовательского рейтинга жанра Action')
# '#ff8800' - мандариновый
# Out:
# count    389.000000
# mean       6.837532
# std        1.330173
# min        2.000000
# 25%        6.300000
# 50%        7.100000
# 75%        7.800000
# max        9.100000
# Name: user_score, dtype: float64
# Text(0.5, 1.0, 'График пользовательского рейтинга жанра Action')

# %%
display(df_game_actual.query('genre == "Sports"')['user_score'].describe())
df_game_actual.query('genre == "Sports"')['user_score'].plot(kind='hist',grid=True, figsize=(7, 5), color='#ff8800')
plt.title('График пользовательского рейтинга жанра Sports')
# Out:
# count    160.000000
# mean       5.238125
# std        1.783427
# min        0.200000
# 25%        4.100000
# 50%        5.500000
# 75%        6.500000
# max        8.800000
# Name: user_score, dtype: float64
# Text(0.5, 1.0, 'График пользовательского рейтинга жанра Sports')

# %% [markdown]
# Проверим **2-ю** гипотезу:
#
# **H₀** = Средние пользовательские рейтинги жанров Action и Sports не отличаются.
#
# **H₁** = Средние пользовательские рейтинги жанров Action и Sports разные.

# %%
alpha = .01 # критический уровень статистической значимости

results = st.ttest_ind(
    df_game_actual.query('genre == "Action"')['user_score'].dropna(), 
    df_game_actual.query('genre == "Sports"')['user_score'].dropna())

print('p-значение:', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение: 1.0517832389140023e-27
# Отвергаем нулевую гипотезу

# %% [markdown]
# Исходя из графиков и расчетов, а также проверки гипотез, можно сказать, что средние пользовательские рейтинги жанров Action (среднее 6,84) и Sports (среднее 5,24) разные.

# %% [markdown]
# ### Вывод

# %% [markdown]
# После проверки 2 гипотез, можно утверждать, что:
# * Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# * Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
#
# Xbox является разработкой Microsoft, а почти все игры на PC созданы под Windows, поэтому не удивительно, что пользовательские оценки похожи.
#
# А вот жанры Action и Sports довольно различны и игроки к ним относятся по-разному. Зачастую игры жанра Спорт выходят хуже по качеству, каждый год разработчики выпускают игру под новым новером без каких-либо изменений, поэтому (25% игр жанра спорт имеют оценку 4,1) гипотеза подтвердилась.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# * В середине 90-х игровые приставки PC стали более доступными, начался рост выпускаемых игр, пик пришелся на 2008-2009 года, потом пошел на спад, но игры стали более объемными, как по сюжету, так и по качеству графики.
#
# * PS2 -  лидер по количечеству продаж за все время (и количества консолей и количества игр)
#
# * Платформа, в среднем, актуальна 8-10 лет.
#
# * Оценки критиков больше влияют на количество продаж игры, а пользовательские рпактически не влияют.
#
# * Япония отличается от Америки и Европе по популярности жанров и платформ.
#
# * Самые популярные жанры: Action, Shooter, Sports и Role-Playing.
#
# **Закономерности, определяющие успешность игры:**
#
# Чтобы игре стать популярной в 2017 году, она должна быть:
#
# * Выйти на следующих платформах: PS4, XOne (для Европы и Америки) и 3DS (для Японии, а лучше выпустить игру на новую платформу Nintendo Switch), а также на PC, как платформу, которая будет доступна всегда и не устареет (игра может стать популярной как Герои Меча и Магии 3);
# * Жанр должен быть Action, Shooter, Sports (для Европы и Америки) и Action, Role Playing (для Японии);
# * Рейтинг ESRB для Японии - «T» («Teen») — «Подросткам» - от 13 лет, а для Европы и Америки - «M» («Mature») — «Для взрослых» - от 17 лет. Для всех регионов подойдет рейтинг - «E» («Everyone») — «Для всех».
